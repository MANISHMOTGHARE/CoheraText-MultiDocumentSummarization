# %%
import seaborn as sns
import pandas as pd

# Sample data creation
data = {
    'BART': [0.45, 0.44, 0.42, 0.43],
    'Pegasus': [0.44, 0.43, 0.41, 0.42],
    'T5': [0.42, 0.41, 0.39, 0.40],
    'Longformer': [0.39, 0.38, 0.37, 0.36],
    'Pointer-Generator': [0.41, 0.40, 0.38, 0.39]
}
df = pd.DataFrame(data, index=['MultiNews', 'WikiSum', 'DUC', 'CNN/Daily Mail'])

sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title('Model Performance Across Different Datasets')
plt.xlabel('Models')
plt.ylabel('Datasets')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e60fa56109b2> in <cell line: 15>()
#      13
#      14 sns.heatmap(df, annot=True, cmap='coolwarm')
# ---> 15 plt.title('Model Performance Across Different Datasets')
#      16 plt.xlabel('Models')
#      17 plt.ylabel('Datasets')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming data is loaded into a DataFrame named df
data = {
    'Model': ['Pegasus', 'BART', 'T5', 'Longformer (LED)', 'LongT5', 'Hierarchical Transformer', 'GraphSum', 'Pointer-Generator Networks', 'Multi-Source Seq2Seq', 'DANCER', 'PRIMERA', 'SCROLLS', 'UniMS', 'GSum', 'FLEX', 'SLED', 'MReaL'],
    'ROUGE-1': [0.441, 0.442, 0.430, 0.220, 0.320, 0.425, 0.400, 0.380, 0.410, 0.430, 0.422, 0.415, 0.432, 0.410, 0.425, 0.417, 0.423],
    'ROUGE-2': [0.222, 0.224, 0.211, 0.120, 0.140, 0.210, 0.192, 0.170, 0.200, 0.215, 0.210, 0.205, 0.218, 0.202, 0.212, 0.208, 0.216],
    'ROUGE-L': [0.336, 0.338, 0.320, 0.170, 0.210, 0.318, 0.310, 0.290, 0.315, 0.328, 0.325, 0.320, 0.330, 0.312, 0.327, 0.323, 0.331],
    'Average Precision': [0.320, 0.325, 0.310, 0.190, 0.230, 0.312, 0.300, 0.275, 0.305, 0.318, 0.315, 0.310, 0.320, 0.307, 0.316, 0.312, 0.318]
}

df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(14, 10))
sns.barplot(data=df, x='ROUGE-1', y='Model')
plt.title('Comparison of ROUGE-1 Scores Across Models')
plt.xlabel('ROUGE-1 Score')
plt.ylabel('Model')
plt.show()

# %%
# prompt: download the above chart

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from google.colab import files

# ... (Your existing code for creating the heatmap and barplot) ...

# Save the heatmap as a PNG file
plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title('Model Performance Across Different Datasets')
plt.xlabel('Models')
plt.ylabel('Datasets')
plt.savefig('heatmap.png')

# Save the barplot as a PNG file
plt.figure(figsize=(14, 10))
sns.barplot(data=df, x='ROUGE-1', y='Model')
plt.title('Comparison of ROUGE-1 Scores Across Models')
plt.xlabel('ROUGE-1 Score')
plt.ylabel('Model')
plt.savefig('barplot.png')


# Download the PNG files
files.download('heatmap.png')
files.download('barplot.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-04743ec6448e> in <cell line: 12>()
#      10 # Save the heatmap as a PNG file
#      11 plt.figure(figsize=(10, 6))
# ---> 12 sns.heatmap(df, annot=True, cmap='coolwarm')
#      13 plt.title('Model Performance Across Different Datasets')
#      14 plt.xlabel('Models')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data from the provided table
data = {
    'Model': ['Pegasus', 'BART', 'T5', 'Longformer (LED)', 'LongT5', 'Hierarchical Transformer', 'GraphSum', 'Pointer-Generator Networks', 'Multi-Source Seq2Seq', 'DANCER', 'PRIMERA', 'SCROLLS', 'UniMS', 'GSum', 'FLEX', 'SLED', 'MReaL'],
    'ROUGE-1': [0.441, 0.442, 0.430, 0.220, 0.320, 0.425, 0.400, 0.380, 0.410, 0.430, 0.422, 0.415, 0.432, 0.410, 0.425, 0.417, 0.423],
    'ROUGE-2': [0.222, 0.224, 0.211, 0.120, 0.140, 0.210, 0.192, 0.170, 0.200, 0.215, 0.210, 0.205, 0.218, 0.202, 0.212, 0.208, 0.216],
    'ROUGE-L': [0.336, 0.338, 0.320, 0.170, 0.210, 0.318, 0.310, 0.290, 0.315, 0.328, 0.325, 0.320, 0.330, 0.312, 0.327, 0.323, 0.331],
    'Average Precision': [0.320, 0.325, 0.310, 0.190, 0.230, 0.312, 0.300, 0.275, 0.305, 0.318, 0.315, 0.310, 0.320, 0.307, 0.316, 0.312, 0.318]
}

df = pd.DataFrame(data)

# Function to plot bar charts for the given metric
def plot_metric(metric_name):
    plt.figure(figsize=(14, 8))
    bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
    plt.title(f'Comparison of {metric_name} Scores Across Models')
    plt.xlabel(f'{metric_name} Score')
    plt.ylabel('Model')
    for bar in bar_plot.patches:
        bar_plot.annotate(format(bar.get_width(), '.3f'),
                   (bar.get_width(), bar.get_y() + bar.get_height() / 2),
                   ha = 'left', va = 'center',
                   size=10, xytext = (5, 0),
                   textcoords = 'offset points')
    plt.show()

# Plotting ROUGE-2, ROUGE-L, and Average Precision
plot_metric('ROUGE-2')
plot_metric('ROUGE-L')
plot_metric('Average Precision')
# Out:
# <ipython-input-4-82756f319d63>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
# <ipython-input-4-82756f319d63>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
# <ipython-input-4-82756f319d63>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data from the provided table
data = {
    'Model': ['Pegasus', 'BART', 'T5', 'Longformer (LED)', 'LongT5', 'Hierarchical Transformer', 'GraphSum', 'Pointer-Generator Networks', 'Multi-Source Seq2Seq', 'DANCER', 'PRIMERA', 'SCROLLS', 'UniMS', 'GSum', 'FLEX', 'SLED', 'MReaL'],
    'ROUGE-1': [0.441, 0.442, 0.430, 0.220, 0.320, 0.425, 0.400, 0.380, 0.410, 0.430, 0.422, 0.415, 0.432, 0.410, 0.425, 0.417, 0.423],
    'ROUGE-2': [0.222, 0.224, 0.211, 0.120, 0.140, 0.210, 0.192, 0.170, 0.200, 0.215, 0.210, 0.205, 0.218, 0.202, 0.212, 0.208, 0.216],
    'ROUGE-L': [0.336, 0.338, 0.320, 0.170, 0.210, 0.318, 0.310, 0.290, 0.315, 0.328, 0.325, 0.320, 0.330, 0.312, 0.327, 0.323, 0.331],
    'Average Precision': [0.320, 0.325, 0.310, 0.190, 0.230, 0.312, 0.300, 0.275, 0.305, 0.318, 0.315, 0.310, 0.320, 0.307, 0.316, 0.312, 0.318]
}

df = pd.DataFrame(data)

# Function to plot and save bar charts for the given metric
def plot_and_save_metric(metric_name):
    plt.figure(figsize=(14, 8))
    bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
    plt.title(f'Comparison of {metric_name} Scores Across Models')
    plt.xlabel(f'{metric_name} Score')
    plt.ylabel('Model')

    # Annotating bars with values
    for bar in bar_plot.patches:
        bar_plot.annotate(format(bar.get_width(), '.3f'),
                   (bar.get_width(), bar.get_y() + bar.get_height() / 2),
                   ha = 'left', va = 'center',
                   size=10, xytext = (5, 0),
                   textcoords = 'offset points')

    # Save the plot to a file
    plt.savefig(f"{metric_name}_scores_comparison.png", bbox_inches='tight')
    plt.show()

# Plotting and saving ROUGE-2, ROUGE-L, and Average Precision
plot_and_save_metric('ROUGE-2')
plot_and_save_metric('ROUGE-L')
plot_and_save_metric('Average Precision')
# Out:
# <ipython-input-5-464c7590b668>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
# <ipython-input-5-464c7590b668>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
# <ipython-input-5-464c7590b668>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data from the provided table
data = {
    'Model': ['Pegasus', 'BART', 'T5', 'Longformer (LED)', 'LongT5', 'Hierarchical Transformer', 'GraphSum', 'Pointer-Generator Networks', 'Multi-Source Seq2Seq', 'DANCER', 'PRIMERA', 'SCROLLS', 'UniMS', 'GSum', 'FLEX', 'SLED', 'MReaL'],
    'ROUGE-1': [0.441, 0.442, 0.430, 0.220, 0.320, 0.425, 0.400, 0.380, 0.410, 0.430, 0.422, 0.415, 0.432, 0.410, 0.425, 0.417, 0.423],
    'ROUGE-2': [0.222, 0.224, 0.211, 0.120, 0.140, 0.210, 0.192, 0.170, 0.200, 0.215, 0.210, 0.205, 0.218, 0.202, 0.212, 0.208, 0.216],
    'ROUGE-L': [0.336, 0.338, 0.320, 0.170, 0.210, 0.318, 0.310, 0.290, 0.315, 0.328, 0.325, 0.320, 0.330, 0.312, 0.327, 0.323, 0.331],
    'Average Precision': [0.320, 0.325, 0.310, 0.190, 0.230, 0.312, 0.300, 0.275, 0.305, 0.318, 0.315, 0.310, 0.320, 0.307, 0.316, 0.312, 0.318]
}

df = pd.DataFrame(data)

# Function to plot and save bar charts for the given metric
def plot_and_save_metric(metric_name):
    plt.figure(figsize=(14, 8))
    bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
    plt.title(f'Comparison of {metric_name} Scores Across Models')
    plt.xlabel(f'{metric_name} Score')
    plt.ylabel('Model')

    # Annotating bars with values
    for bar in bar_plot.patches:
        bar_plot.annotate(format(bar.get_width(), '.3f'),
                   (bar.get_width(), bar.get_y() + bar.get_height() / 2),
                   ha = 'left', va = 'center',
                   size=10, xytext = (5, 0),
                   textcoords = 'offset points')

    # Save the plot to a file
    plt.savefig(f"{metric_name}_scores_comparison.png", bbox_inches='tight')
    plt.show()

# Plotting and saving ROUGE-2, ROUGE-L, and Average Precision
plot_and_save_metric('ROUGE-2')
plot_and_save_metric('ROUGE-L')
plot_and_save_metric('Average Precision')
# Out:
# <ipython-input-6-464c7590b668>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
# <ipython-input-6-464c7590b668>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
# <ipython-input-6-464c7590b668>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=df, x=metric_name, y='Model', palette="viridis")
